# %%
import pandas as pd
import numpy as np
import joblib
import faiss

# %%
from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
df1 = pd.read_csv("datasets/fake_job_postings.csv")
df2 = pd.read_csv("datasets/Fake Postings.csv")

# %%
print("Dataset 1 shape:", df1.shape)
print("Dataset 2 shape:", df2.shape)
# Out:
# Dataset 1 shape: (17880, 18)
# Dataset 2 shape: (10000, 10)

# %%
df1.columns = df1.columns.str.lower()
df2.columns = df2.columns.str.lower()

# %%
common_cols = list(set(df1.columns).intersection(set(df2.columns)))

# %%
df1 = df1[common_cols]
df2 = df2[common_cols]

# %%
df = pd.concat([df1, df2], ignore_index=True)

# Remove duplicates
df = df.drop_duplicates()

# %%
print("Final merged dataset shape:", df.shape)
# Out:
# Final merged dataset shape: (27566, 10)

# %%
print(df.columns)
# Out:
# Index(['requirements', 'benefits', 'company_profile', 'industry',
#        'description', 'salary_range', 'fraudulent', 'location', 'title',
#        'employment_type'],
#       dtype='object')

# %%
text_cols = [
    "title",
    "company_profile",
    "description",
    "requirements",
    "benefits",
    "employment_type",
    "industry"
]

# %%
df[text_cols] = df[text_cols].fillna("")

# %%
df.head()
# Out:
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  \
# 0
# 1  What you will get from usThrough being part of...
# 2
# 3  Our culture is anything but corporate—we have ...
# 4                              Full Benefits Offered
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                     industry  \
# 0
# 1  Marketing and Advertising
# 2
# 3          Computer Software
# 4     Hospital & Health Care
#
#                                          description salary_range  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...          NaN           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...          NaN           0
# 2  Our client, located in Houston, is actively se...          NaN           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...          NaN           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...          NaN           0
#
#              location                                      title  \
# 0    US, NY, New York                           Marketing Intern
# 1      NZ, , Auckland  Customer Service - Cloud Video Production
# 2       US, IA, Wever    Commissioning Machinery Assistant (CMA)
# 3  US, DC, Washington          Account Executive - Washington DC
# 4  US, FL, Fort Worth                        Bill Review Manager
#
#   employment_type
# 0           Other
# 1       Full-time
# 2
# 3       Full-time
# 4       Full-time

# %%
df["combined_text"] = df[text_cols].agg(" ".join, axis=1)

# %%
df.head()
# Out:
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  \
# 0
# 1  What you will get from usThrough being part of...
# 2
# 3  Our culture is anything but corporate—we have ...
# 4                              Full Benefits Offered
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                     industry  \
# 0
# 1  Marketing and Advertising
# 2
# 3          Computer Software
# 4     Hospital & Health Care
#
#                                          description salary_range  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...          NaN           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...          NaN           0
# 2  Our client, located in Houston, is actively se...          NaN           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...          NaN           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...          NaN           0
#
#              location                                      title  \
# 0    US, NY, New York                           Marketing Intern
# 1      NZ, , Auckland  Customer Service - Cloud Video Production
# 2       US, IA, Wever    Commissioning Machinery Assistant (CMA)
# 3  US, DC, Washington          Account Executive - Washington DC
# 4  US, FL, Fort Worth                        Bill Review Manager
#
#   employment_type                                      combined_text
# 0           Other  Marketing Intern We're Food52, and we've creat...
# 1       Full-time  Customer Service - Cloud Video Production 90 S...
# 2                  Commissioning Machinery Assistant (CMA) Valor ...
# 3       Full-time  Account Executive - Washington DC Our passion ...
# 4       Full-time  Bill Review Manager SpotSource Solutions LLC i...

# %%
df["label"] = df["fraudulent"].astype(int)

# %%
df.head(1)
# Out:
#                                         requirements benefits  \
# 0  Experience with content management systems a m...
#
#                                      company_profile industry  \
# 0  We're Food52, and we've created a groundbreaki...
#
#                                          description salary_range  fraudulent  \
# 0  Food52, a fast-growing, James Beard Award-winn...          NaN           0
#
#            location             title employment_type  \
# 0  US, NY, New York  Marketing Intern           Other
#
#                                        combined_text  label
# 0  Marketing Intern We're Food52, and we've creat...      0

# %%
embedder = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
embeddings = embedder.encode(
    df["combined_text"].tolist(),
    show_progress_bar=True,
    batch_size=32
)
# Out:
# Batches:   0%|          | 0/862 [00:00<?, ?it/s]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    embeddings,
    df["label"],
    test_size=0.2,
    stratify=df["label"],
    random_state=42
)

# %%
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print("\nMODEL REPORT\n")
print(classification_report(y_test, clf.predict(X_test)))
# Out:
# MODEL REPORT
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3343
#            1       0.98      0.95      0.96      2171
#
#     accuracy                           0.97      5514
#    macro avg       0.97      0.97      0.97      5514
# weighted avg       0.97      0.97      0.97      5514

# %%
joblib.dump(clf, "job_scam_classifier.pkl")
joblib.dump(embedder, "text_embedder.pkl")
# Out:
# ['text_embedder.pkl']

# %%
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings)

# %%
faiss.write_index(index, "job_memory.index")
joblib.dump(df[["combined_text", "label"]], "job_memory_meta.pkl")

print("\n ALL FINAL PKL FILES CREATED")
# Out:
#  ALL FINAL PKL FILES CREATED

# %%
# import numpy as np
# import torch
# import faiss
# from sentence_transformers import SentenceTransformer

# print("NumPy OK:", np.__version__)
# print("Torch OK:", torch.__version__)

# model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# emb = model.encode(["test sentence"])
# print("Embedding shape:", emb.shape)
